# %%
import pandas as pd
from distutils.version import StrictVersion
import matplotlib.pyplot as plt

from pandasql import sqldf
dfsql = lambda q: sqldf(q, globals())

pd.set_option('display.max_columns', 500)
plt.rcParams['figure.figsize'] = [15,3]

# %%
df = pd.read_parquet('./parquet_conversion/deduped.lateral.parquet', engine='pyarrow')

# %%
df['date'] = df.gameCreation.dt.date

# %%
def extractShortVersion(x):
    split_array = x.split('.')
    major = split_array[0]
    minor = split_array[1]
    if len(minor) < 2:
        minor = "0{num}".format(num=minor)
    return "{major}.{minor}".format(major=major, minor=minor)

df['shortVersion'] = df.gameVersion.apply(extractShortVersion)
# df['ver'] = df['shortVersion'].apply(StrictVersion)

# %%
df.head()
# Out:
#              gameCreation  gameDuration      gameId gameMode      gameType  \
# 0 2018-01-01 01:44:02.009           866  2684129583  SNOWURF  MATCHED_GAME
# 1 2018-01-01 01:44:02.009           866  2684129583  SNOWURF  MATCHED_GAME
# 2 2018-01-01 01:44:02.009           866  2684129583  SNOWURF  MATCHED_GAME
# 3 2018-01-01 01:44:02.009           866  2684129583  SNOWURF  MATCHED_GAME
# 4 2018-01-01 01:44:02.009           866  2684129583  SNOWURF  MATCHED_GAME
#
#      gameVersion  mapId platformId  queueId  seasonId  participantId  \
# 0  7.24.212.5337     11        NA1     1010         9              1
# 1  7.24.212.5337     11        NA1     1010         9              2
# 2  7.24.212.5337     11        NA1     1010         9              3
# 3  7.24.212.5337     11        NA1     1010         9              4
# 4  7.24.212.5337     11        NA1     1010         9              5
#
#    player.accountId  player.currentAccountId player.currentPlatformId  \
# ...

# %%
fig, axs = plt.subplots(1,2)
df.groupby(['gameMode'])['gameId'].nunique().plot(kind='bar', ax=axs[0])
df.sort_values(by='date').groupby(['shortVersion'])['gameId'].nunique().plot(kind='bar', ax=axs[1])

# %%
df.groupby(['gameMode'])['gameId'].nunique().plot(kind='bar')
df.sort_values(by='date').groupby(['shortVersion'])['gameId'].nunique().plot(kind='bar')

# %%
df.groupby(['date', 'gameMode'])['gameId'].nunique().unstack('gameMode').plot(kind='bar', stacked=True)
